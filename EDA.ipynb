# %% [markdown]
# STEP1:
#
# DATA SET OVERVIEW
#
# The data set is Aspiring Mind Employment Outcome 2015 (AMEO)The data set contains 3998 rows and 39 columns.The dataset contains both numerical and categorical data

# %% [markdown]
# STEP 2: Import the data and display the head, shape and description of the data.

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Tarun\Desktop\INNOMATICS\INTERNSHIP\EDA\data.xlsx - Sheet1.csv")
df
# Out:
#      Unnamed: 0      ID     Salary           DOJ           DOL  \
# 0         train  203097   420000.0   6/1/12 0:00       present
# 1         train  579905   500000.0   9/1/13 0:00       present
# 2         train  810601   325000.0   6/1/14 0:00       present
# 3         train  267447  1100000.0   7/1/11 0:00       present
# 4         train  343523   200000.0   3/1/14 0:00   3/1/15 0:00
# ...         ...     ...        ...           ...           ...
# 3993      train   47916   280000.0  10/1/11 0:00  10/1/12 0:00
# 3994      train  752781   100000.0   7/1/13 0:00   7/1/13 0:00
# 3995      train  355888   320000.0   7/1/13 0:00       present
# 3996      train  947111   200000.0   7/1/14 0:00   1/1/15 0:00
# 3997      train  324966   400000.0   2/1/13 0:00       present
#
#                       Designation           JobCity Gender           DOB  \
# 0         senior quality engineer         Bangalore      f  2/19/90 0:00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 39 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             3998 non-null   object
#  1   ID                     3998 non-null   int64
#  2   Salary                 3998 non-null   float64
#  3   DOJ                    3998 non-null   object
#  4   DOL                    3998 non-null   object
#  5   Designation            3998 non-null   object
#  6   JobCity                3998 non-null   object
#  7   Gender                 3998 non-null   object
#  8   DOB                    3998 non-null   object
#  9   10percentage           3998 non-null   float64
#  10  10board                3998 non-null   object
#  11  12graduation           3998 non-null   int64
#  12  12percentage           3998 non-null   float64
#  13  12board                3998 non-null   object
# ...

# %%
df['Unnamed: 0'].value_counts()
# Out:
# train    3998
# Name: Unnamed: 0, dtype: int64

# %%
df.describe()
# Out:
#                  ID        Salary  10percentage  12graduation  12percentage  \
# count  3.998000e+03  3.998000e+03   3998.000000   3998.000000   3998.000000
# mean   6.637945e+05  3.076998e+05     77.925443   2008.087544     74.466366
# std    3.632182e+05  2.127375e+05      9.850162      1.653599     10.999933
# min    1.124400e+04  3.500000e+04     43.000000   1995.000000     40.000000
# 25%    3.342842e+05  1.800000e+05     71.680000   2007.000000     66.000000
# 50%    6.396000e+05  3.000000e+05     79.150000   2008.000000     74.400000
# 75%    9.904800e+05  3.700000e+05     85.670000   2009.000000     82.600000
# max    1.298275e+06  4.000000e+06     97.760000   2013.000000     98.700000
#
#           CollegeID  CollegeTier   collegeGPA  CollegeCityID  CollegeCityTier  \
# count   3998.000000  3998.000000  3998.000000    3998.000000      3998.000000
# mean    5156.851426     1.925713    71.486171    5156.851426         0.300400
# ...

# %%
for i in df.columns:
    #print(i,'\n',data[i].value_counts(),'\n','***'*20,'\n')
    print(f'Column name: [{i}]\n{df[i].value_counts()}\n','***'*20,'\n')
# Out:
# Column name: [Unnamed: 0]
# train    3998
# Name: Unnamed: 0, dtype: int64
#  ************************************************************
#
# Column name: [ID]
# 203097     1
# 283847     1
# 1118955    1
# 327371     1
# 587792     1
#           ..
# 355018     1
# 806160     1
# 102065     1
# 462964     1
# 324966     1
# Name: ID, Length: 3998, dtype: int64
#  ************************************************************
#
# Column name: [Salary]
# 300000.0     293
# 180000.0     239
# 200000.0     205
# 325000.0     188
# 120000.0     165
#             ...
# 2050000.0      1
# 144000.0       1
# 1320000.0      1
# 755000.0       1
# 925000.0       1
# Name: Salary, Length: 177, dtype: int64
#  ************************************************************
#
# Column name: [DOJ]
# 7/1/14 0:00     199
# 6/1/14 0:00     180
# 8/1/14 0:00     178
# 9/1/14 0:00     142
# 1/1/14 0:00     142
#                ...
# 11/1/15 0:00      1
# 11/1/09 0:00      1
# 8/1/04 0:00       1
# ...

# %% [markdown]
# DATA CLEANING

# %%
df.drop(["Unnamed: 0","DOJ","DOL","CollegeCityID","CollegeCityTier","Domain","ComputerProgramming","ElectronicsAndSemicon","ComputerScience","MechanicalEngg"
        ,"ElectricalEngg","TelecomEngg","CivilEngg"],axis=1,inplace=True)

# %%
df
# Out:
#           ID     Salary                  Designation           JobCity Gender  \
# 0     203097   420000.0      senior quality engineer         Bangalore      f
# 1     579905   500000.0            assistant manager            Indore      m
# 2     810601   325000.0             systems engineer           Chennai      f
# 3     267447  1100000.0     senior software engineer           Gurgaon      m
# 4     343523   200000.0                          get           Manesar      m
# ...      ...        ...                          ...               ...    ...
# 3993   47916   280000.0            software engineer        New Delhi       m
# 3994  752781   100000.0             technical writer         Hyderabad      f
# 3995  355888   320000.0  associate software engineer         Bangalore      m
# 3996  947111   200000.0           software developer  Asifabadbanglore      f
# 3997  324966   400000.0      senior systems engineer           Chennai      f
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     3998 non-null   int64
#  1   Salary                 3998 non-null   float64
#  2   Designation            3998 non-null   object
#  3   JobCity                3998 non-null   object
#  4   Gender                 3998 non-null   object
#  5   DOB                    3998 non-null   object
#  6   10percentage           3998 non-null   float64
#  7   10board                3998 non-null   object
#  8   12graduation           3998 non-null   int64
#  9   12percentage           3998 non-null   float64
#  10  12board                3998 non-null   object
#  11  CollegeID              3998 non-null   int64
#  12  CollegeTier            3998 non-null   int64
#  13  Degree                 3998 non-null   object
# ...

# %% [markdown]
# The data set doesnot contains any null values

# %%
df.columns
# Out:
# Index(['ID', 'Salary', 'Designation', 'JobCity', 'Gender', 'DOB',
#        '10percentage', '10board', '12graduation', '12percentage', '12board',
#        'CollegeID', 'CollegeTier', 'Degree', 'Specialization', 'collegeGPA',
#        'CollegeState', 'GraduationYear', 'English', 'Logical', 'Quant',
#        'conscientiousness', 'agreeableness', 'extraversion', 'nueroticism',
#        'openess_to_experience'],
#       dtype='object')

# %%
df['GraduationYear'].value_counts()
# Out:
# 2013    1181
# 2014    1036
# 2012     847
# 2011     507
# 2010     292
# 2015      94
# 2009      24
# 2017       8
# 2016       7
# 0          1
# 2007       1
# Name: GraduationYear, dtype: int64

# %%
df.drop(df[df["GraduationYear"]==0].index,inplace=True)
df
# Out:
#           ID     Salary                  Designation           JobCity Gender  \
# 0     203097   420000.0      senior quality engineer         Bangalore      f
# 1     579905   500000.0            assistant manager            Indore      m
# 2     810601   325000.0             systems engineer           Chennai      f
# 3     267447  1100000.0     senior software engineer           Gurgaon      m
# 4     343523   200000.0                          get           Manesar      m
# ...      ...        ...                          ...               ...    ...
# 3993   47916   280000.0            software engineer        New Delhi       m
# 3994  752781   100000.0             technical writer         Hyderabad      f
# 3995  355888   320000.0  associate software engineer         Bangalore      m
# 3996  947111   200000.0           software developer  Asifabadbanglore      f
# 3997  324966   400000.0      senior systems engineer           Chennai      f
#
# ...

# %% [markdown]
# Removing the data point with graduation year mentioned as 0

# %%
df['Salary'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Salary'].describe()
# Out:
# count    3.997000e+03
# mean     3.076955e+05
# std      2.127639e+05
# min      3.500000e+04
# 25%      1.800000e+05
# 50%      3.000000e+05
# 75%      3.700000e+05
# max      4.000000e+06
# Name: Salary, dtype: float64

# %% [markdown]
# Here in salary columns we can observe that so many outliers but in real world scenario we cant mention the values as outliers because they are earning high salary with respect to their experience and so many factors

# %%
df['10percentage'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# Based upon 10percentage column we can remove the data points with percentage less than 35 we can drop those outliers

# %%
df['12percentage'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['collegeGPA'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['collegeGPA'].value_counts()
# Out:
# 70.00    112
# 72.00     99
# 75.00     83
# 65.00     79
# 68.00     75
#         ...
# 69.01      1
# 58.86      1
# 73.17      1
# 60.89      1
# 70.42      1
# Name: collegeGPA, Length: 1281, dtype: int64

# %% [markdown]
# Based upon collegeGPA column we can remove the data points with GPA less than 20 we can drop those outliers

# %%
df.drop(df[df["collegeGPA"]<20].index,inplace=True)
df
# Out:
#           ID     Salary                  Designation           JobCity Gender  \
# 0     203097   420000.0      senior quality engineer         Bangalore      f
# 1     579905   500000.0            assistant manager            Indore      m
# 2     810601   325000.0             systems engineer           Chennai      f
# 3     267447  1100000.0     senior software engineer           Gurgaon      m
# 4     343523   200000.0                          get           Manesar      m
# ...      ...        ...                          ...               ...    ...
# 3993   47916   280000.0            software engineer        New Delhi       m
# 3994  752781   100000.0             technical writer         Hyderabad      f
# 3995  355888   320000.0  associate software engineer         Bangalore      m
# 3996  947111   200000.0           software developer  Asifabadbanglore      f
# 3997  324966   400000.0      senior systems engineer           Chennai      f
#
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Plotting distribution of percentages or gpa of the data points

# %%
sns.kdeplot(data=df, x="10percentage")
# Out:
# <Axes: xlabel='10percentage', ylabel='Density'>

# %% [markdown]
# From the above kde distribution graph we can say that most of the employees are scored between 80% to 85 % in their 10th standard

# %%
sns.kdeplot(data=df, x="12percentage")
# Out:
# <Axes: xlabel='12percentage', ylabel='Density'>

# %% [markdown]
# From the above kde distribution graph we can say that most of the employees are scored between 65% to 85 % in their 12th standard

# %%
sns.kdeplot(data=df, x="collegeGPA")
# Out:
# <Axes: xlabel='collegeGPA', ylabel='Density'>

# %% [markdown]
# From the above kde distribution graph we can say that most of the employees are scored between 65% to 80 % in their college

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
fig=plt.subplots(figsize=(50,20))
plt.xticks(rotation=90)
sns.countplot(x=df['JobCity'])
# Out:
# <Axes: xlabel='JobCity', ylabel='count'>

# %%
fig=plt.subplots(figsize=(10,7))
sns.countplot( x=df['Degree'])
# Out:
# <Axes: xlabel='Degree', ylabel='count'>

# %% [markdown]
# BTECH students are highest number of employees in the company

# %%
fig=plt.subplots(figsize=(20,10))
plt.xticks(rotation=90)
sns.countplot(x = df['CollegeState'])
# Out:
# <Axes: xlabel='CollegeState', ylabel='count'>

# %% [markdown]
# The most of the employee's are from Uttar pradesh

# %% [markdown]
# # BIVARIATE ANALYSIS

# %%
fig=plt.subplots(figsize=(15,7))
plt.xticks(rotation=90)
sns.scatterplot(x = "Specialization", y = "Salary", data = df, hue = "Gender",hue_order= ['m', 'f'])
# Out:
# <Axes: xlabel='Specialization', ylabel='Salary'>

# %% [markdown]
# This scatter plot tells about the specialization and salary of the employee's and Gender how many employee's are from male and the how many employee's are from female
